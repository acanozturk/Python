# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Alican\\03-Python Data Science Bootcamp\\mpg.csv')

# %%
df.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# ...

# %%
df['model_year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
df['model_year'].value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 81    29
# 80    29
# 79    29
# 70    29
# 77    28
# 72    28
# 71    28
# 74    27
# Name: model_year, dtype: int64

# %%
df.groupby(by = ['model_year', 'origin']).describe()
# Out:
#                     mpg                                                     \
#                   count       mean        std   min     25%    50%     75%
# model_year origin
# 70         1       22.0  15.272727   3.507568   9.0  14.000  15.00  17.750
#            2        5.0  25.200000   0.836660  24.0  25.000  25.00  26.000
#            3        2.0  25.500000   2.121320  24.0  24.750  25.50  26.250
# 71         1       20.0  18.100000   4.655500  12.0  14.000  18.00  19.750
#            2        4.0  28.750000   1.500000  27.0  27.750  29.00  30.000
#            3        4.0  29.500000   4.434712  25.0  26.500  29.00  32.000
# 72         1       18.0  16.277778   4.860471  11.0  13.000  14.00  19.250
#            2        5.0  22.000000   2.915476  18.0  21.000  22.00  23.000
#            3        5.0  24.200000   3.563706  19.0  23.000  24.00  27.000
# 73         1       29.0  15.034483   3.212506  11.0  13.000  14.00  18.000
# ...

# %%
year_origin = df.groupby(by = ['model_year', 'origin']).mean()

# %%
year_origin.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [1, 2, 3]])

# %%
year_origin.xs(key = 1, level = 'origin') # We can access interior level values, in this case origin
# Out:
#                   mpg  cylinders  displacement       weight  acceleration
# model_year
# 70          15.272727   7.636364    336.909091  3716.500000     11.977273
# 71          18.100000   6.200000    257.000000  3401.600000     14.575000
# 72          16.277778   6.888889    281.250000  3682.666667     14.055556
# 73          15.034483   7.241379    314.103448  3821.448276     13.620690
# 74          18.333333   6.266667    236.066667  3503.333333     15.966667
# 75          17.550000   6.400000    253.400000  3533.200000     16.350000
# 76          19.431818   6.363636    243.954545  3405.409091     15.786364
# 77          20.722222   6.222222    242.333333  3422.000000     15.238889
# 78          21.772727   6.000000    217.545455  3141.136364     15.545455
# 79          23.478261   6.260870    231.260870  3210.217391     15.243478
# 80          25.914286   4.285714    151.571429  2822.428571     16.800000
# ...

# %%
df.agg(['std', 'mean'])
# Out:
#             mpg  cylinders  displacement       weight  acceleration  \
# std    7.815984   1.701004    104.269838   846.841774      2.757689
# mean  23.514573   5.454774    193.425879  2970.424623     15.568090
#
#       model_year    origin
# std     3.697627  0.802055
# mean   76.010050  1.572864

# %%
df.agg({'mpg':['max', 'mean'], 'weight':['mean', 'std']})
# Out:
#             mpg       weight
# max   46.600000          NaN
# mean  23.514573  2970.424623
# std         NaN   846.841774
